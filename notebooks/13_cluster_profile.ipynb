# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)

# %%
df = pd.read_csv('../datasets/master/master_final_2025.csv')
feat_cols = ['facility_ratio_jhs','facility_ratio_shs','school_density_primary',
            'library_per_1000pupils','literacy_total','eys_avg','gap_literacy','gap_eys']
profile = df.groupby('kmeans_cluster')[feat_cols].mean().round(2)
profile['n'] = df.groupby('kmeans_cluster').size()
print(profile)
# Out:
#                 facility_ratio_jhs  facility_ratio_shs  school_density_primary  library_per_1000pupils  literacy_total  eys_avg  gap_literacy  gap_eys   n
# kmeans_cluster
# 0                             0.49                0.22                    7.49                    0.95           97.83    13.50         -1.55     0.36  26
# 1                             0.32                0.10                    4.28                    0.00           77.07     9.80         -4.46    -0.07   2
# 2                             0.80                0.51                    4.50                    0.84           97.54    13.51         -1.87     0.20   5
# 3                             0.58                0.24                    7.28                    6.42           96.94    13.70         -2.22     0.49   5
